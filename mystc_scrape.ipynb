# %%
#install google play scraper
pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.4-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

# %%
from google_play_scraper import Sort, reviews_all


stc_reviews = reviews_all(
    'com.stc',
    sleep_milliseconds=0, # defaults to 0
    lang='en', # defaults to 'en'
    
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
)

# %%
df = pd.DataFrame(np.array(stc_reviews),columns=['review'])


df = df.join(pd.DataFrame(df.pop('review').tolist()))



df.head()
# Out:
#                                reviewId                userName  \
# 0  c1165a53-de67-4e98-b5ce-a887bfa06c0a  Ataullah Ibrar hussain
# 1  6f47be56-a091-4c4e-a250-411d58999df6             Jasim Uddin
# 2  0c7fbe3a-cca8-493b-892e-a9252fe9dc04                md liton
# 3  bfb20d33-a112-4b6e-818c-0986a815c750       ak moose (AK45CC)
# 4  a2b24738-dc21-4023-aa9b-90acc3b6987c          Qamar Abajober
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/AAcHTt...
# 1  https://play-lh.googleusercontent.com/a/AAcHTt...
# 2  https://play-lh.googleusercontent.com/a-/AD_cM...
# 3  https://play-lh.googleusercontent.com/a-/AD_cM...
# 4  https://play-lh.googleusercontent.com/a/AAcHTt...
#
#                                              content  score  thumbsUpCount  \
# 0  Not good sarvice don't take stc sim i hate thi...      1              0
# 1                               Jasim Uddin 90908090      1              0
# 2                                          best apps      5              0
# 3  I overpaid my bill. When trying to refund open...      1              0
# 4                                               Good      3              0
#
#   reviewCreatedVersion                  at  \
# 0                 None 2023-05-25 16:10:14
# 1               4.36.0 2023-05-25 12:59:18
# 2               4.35.0 2023-05-25 08:33:48
# 3               4.37.0 2023-05-25 08:18:13
# 4               4.36.0 2023-05-24 22:17:37
#
#                                         replyContent           repliedAt  \
# 0  Hi ✋\nWe are at your service around the clock ... 2023-05-26 06:21:48
# 1                                               None                 NaT
# 2  Hello ✋\nWe are pleased with your experience a... 2023-05-26 06:15:45
# 3  Hi ✋\nWe are at your service around the clock ... 2023-05-26 06:21:08
# 4  Hello ✋\nWe are pleased with your experience a... 2023-05-26 06:15:28
#
#   appVersion
# 0       None
# 1     4.36.0
# 2     4.35.0
# 3     4.37.0
# 4     4.36.0

# %%
df.to_csv('stc_reviews.csv', index=False)
