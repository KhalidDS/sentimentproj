# %%
#install google play scraper
# !pip install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in c:\users\admin\anaconda3\lib\site-packages (1.2.4)

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

# %%
from google_play_scraper import Sort, reviews_all


stcpay_reviews = reviews_all(
    'sa.com.stcpay',
    sleep_milliseconds=0, # defaults to 0
    lang='en', # defaults to 'en'
    
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
)

# %%
df = pd.DataFrame(np.array(stcpay_reviews),columns=['review'])


df = df.join(pd.DataFrame(df.pop('review').tolist()))



df.head()
# Out:
#                                reviewId        userName  \
# 0  cbd3f291-3669-4221-b030-c2d5b65d0b81     Sakib Ahmed
# 1  9e01964e-cfaf-48f9-a727-9f746d402208     M A N i A C
# 2  04536120-95a7-4dcf-98ae-027979ea060b  Santosh Thakur
# 3  8269172a-7f9b-4854-85e7-372bd0170e89        ابو يوسف
# 4  4ab08bf2-5a62-46a9-a95c-d4d016f203f3   zeeshan shoeb
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AD_cM...
# 1  https://play-lh.googleusercontent.com/a-/AD_cM...
# 2  https://play-lh.googleusercontent.com/a-/AD_cM...
# 3  https://play-lh.googleusercontent.com/a-/AD_cM...
# 4  https://play-lh.googleusercontent.com/a/AAcHTt...
#
#                                              content  score  thumbsUpCount  \
# 0  Very Poor Application, Specially For Internati...      1              0
# 1                                 Not receive otp 🤷🏻      1              0
# 2                            Very good application 👍      5              0
# 3  تطبيق سئ وخدمة عملاء أسوأ منها .....للأسف حاجز...      1              0
# 4                                               nice      1              0
#
#   reviewCreatedVersion                  at  \
# 0              1.10.30 2023-06-12 09:31:27
# 1                 None 2023-06-12 08:50:26
# 2              1.10.30 2023-06-12 07:29:48
# 3              1.10.30 2023-06-12 03:28:26
# 4                 None 2023-06-12 02:36:11
#
#                                         replyContent           repliedAt  \
# 0                                               None                 NaT
# 1                                               None                 NaT
# 2                                               None                 NaT
# 3  هلا والله ابو يوسف، ياليت تتواصل مع الدعم وتعط... 2022-10-09 05:51:05
# 4                                               None                 NaT
#
#   appVersion
# 0    1.10.30
# 1       None
# 2    1.10.30
# 3    1.10.30
# 4       None

# %%
df.to_csv('stcpay_reviews.csv', index=False)
