# %%
#install google play scraper
# !pip install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in c:\users\admin\anaconda3\lib\site-packages (1.2.4)

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

# %%
from google_play_scraper import Sort, reviews_all


stcpay_reviews = reviews_all(
    'net.gadm.tv',
    sleep_milliseconds=0, # defaults to 0
    lang='en', # defaults to 'en'
    
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
)

# %%
df = pd.DataFrame(np.array(stcpay_reviews),columns=['review'])


df = df.join(pd.DataFrame(df.pop('review').tolist()))



df
# Out:
#                                   reviewId            userName  \
# 0     9d7ecf76-ee66-41ac-a6dd-9de8902d49af   MOHAMMED ALKHAMIS
# 1     2d4f22b1-c39d-4721-8239-96a24553af9c               ya or
# 2     270fc5c7-1b25-4bcd-991f-35189a470d31  Alamin Molla Molla
# 3     9cb85a0a-b7b5-4758-ad76-4d5868e79ed4         OnelNeth TV
# 4     d6dc9dfd-2966-4843-84dc-06039f9f1692      أيمنAiman53-53
# ...                                    ...                 ...
# 1374  54904ccd-cefc-4ee5-9295-2cbaec0ad533       A Google user
# 1375  f6343528-b344-4c9e-98fa-71a47540d7d5       A Google user
# 1376  94a8d60f-d594-473f-b32b-90deddcb1e75       A Google user
# 1377  e32fc915-6782-4e35-819f-94e52272f898       A Google user
# 1378  5785ebe5-0ab6-4f65-aa35-a6eea5dc2079       A Google user
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a-/AD_cM...
# 1     https://play-lh.googleusercontent.com/a-/AD_cM...
# 2     https://play-lh.googleusercontent.com/a-/AD_cM...
# 3     https://play-lh.googleusercontent.com/a-/AD_cM...
# 4     https://play-lh.googleusercontent.com/a-/AD_cM...
# ...                                                 ...
# 1374  https://play-lh.googleusercontent.com/EGemoI2N...
# 1375  https://play-lh.googleusercontent.com/EGemoI2N...
# 1376  https://play-lh.googleusercontent.com/EGemoI2N...
# 1377  https://play-lh.googleusercontent.com/EGemoI2N...
# 1378  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                 content  score  thumbsUpCount  \
# 0     It needs improvement. Very slow in loading up....      2              0
# 1                                 لايعمل مع سامسونج A72      1              0
# 2                           Very nice.Thanks for stc tv      5              0
# 3                    great off or online streaming app.      5              0
# 4     A great application with variety, but I can't ...      3              2
# ...                                                 ...    ...            ...
# 1374                                   جوّي على جوّي⁦❤️      5              1
# 1375                                  It's good network      5              1
# 1376  It just says that I'm using another screen, bu...      1              2
# 1377                   This app not support Android TV.      3              1
# 1378  The app needs a lot of work, it's a good start...      4             11
#
#      reviewCreatedVersion                  at replyContent repliedAt  \
# 0                   6.1.0 2023-06-12 07:13:07         None       NaT
# 1                   6.1.0 2023-06-10 03:53:21         None       NaT
# 2                   6.1.0 2023-06-09 10:59:19         None       NaT
# 3                   6.1.0 2023-06-06 01:01:03         None       NaT
# 4                   6.1.0 2023-06-05 12:06:35         None       NaT
# ...                   ...                 ...          ...       ...
# 1374                 None 2018-04-16 10:06:23         None       NaT
# 1375                2.3.2 2018-04-08 00:17:12         None       NaT
# 1376                2.3.2 2018-03-27 04:43:16         None       NaT
# 1377                 None 2018-03-26 07:44:27         None       NaT
# 1378                2.3.2 2018-03-26 07:30:58         None       NaT
#
#      appVersion
# 0         6.1.0
# 1         6.1.0
# 2         6.1.0
# 3         6.1.0
# 4         6.1.0
# ...         ...
# 1374       None
# 1375      2.3.2
# 1376      2.3.2
# 1377       None
# 1378      2.3.2
#
# [1379 rows x 11 columns]

# %%
df.to_csv('stctv_reviews.csv', index=False)
